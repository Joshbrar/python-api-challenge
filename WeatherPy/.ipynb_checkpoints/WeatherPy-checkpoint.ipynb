# %%
import pandas as pd
import json
import requests
import matplotlib.pyplot as plt
import numpy as np
import random
from api_keys import weather_api_key
#from api_keys import tmdb_key

from citipy import citipy
from datetime import datetime

import scipy.stats as st
from scipy.stats import linregress

# %%
#Generate random lat/lon coordinates
counter = 0
rndlat=[]
rndlon=[]
city_count_input = input("how many cities data do you want to gather?")
while len(rndlat) < int(city_count_input):
    lat = np.random.uniform(-90, 90)
    lon = np.random.uniform(-180,180)
    rndlat.append(lat)
    rndlon.append(lon)
    counter += 1
 
lat_long_df = pd.DataFrame ({"lat": rndlat, "lon":rndlon})
lat_long_df.head()
# Out:
# how many cities data do you want to gather?700
#          lat         lon
# 0 -69.079833  118.136996
# 1  36.351231 -112.382914
# 2  -4.814048  139.490838
# 3  -4.417877  -38.530460
# 4  89.969978  -44.228084

# %%
#get nearest city from the random genereated lat and long values inside dataframe geo_df
city = []
country = []


for index, row in lat_long_df.iterrows():
    city_lat=(row["lat"])
    city_lon=(row["lon"])
    city_name = citipy.nearest_city(city_lat, city_lon).city_name
    country_code = citipy.nearest_city(city_lat, city_lon).country_code
    city.append(city_name)
    country.append(country_code)
    
city_df= pd.DataFrame ({"city": city, "country": country})
city_df.drop_duplicates(["city", "country"])
#Display city and country names
city_df.head()
# Out:
#         city country
# 0     albany      au
# 1  hurricane      us
# 2     kiunga      pg
# 3      ocara      br
# 4  upernavik      gl

# %%
# get the no of cities in the datafram to processed to the weather api 
city_df.count()
# Out:
# city       700
# country    700
# dtype: int64

# %%
city_weather_data=[]
#make API call to weather data and collect the data returened via json calls and handles exceptions appropriately
weather_url="http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{weather_url}appid={weather_api_key}&units={units}&q="
#rate_limiter = RateLimiter(max_calls=50, period=60)
query_url
for index, row in city_df.iterrows():
    #print("hello")
    city_q=row["city"]
    print(city_q)
    response = requests.get(query_url + city_q).json()
    #print(response)
    try:
        temp=response["main"]["temp"]
        humid=response["main"]["humidity"]
        cloud=response["clouds"]["all"]
        wind=response["wind"]["speed"]
        city_lat=response["coord"]["lat"]
        city_lon=response["coord"]["lon"]
        city_name=response["name"]
        city_country=response["sys"]["country"]
        city_weather_data.append({"City": city_name, "Country": city_country, "Latitude": city_lat,"longitude": city_lon,
                                "Temperature (F)": temp, "Humidity (%)": humid, "Cloudiness (%)":cloud, "Wind Speed (MPH)": wind})
        print (f"Processing record #{index+1} -- {city_q}")
        print (f'{weather_url}appid={weather_api_key}&units={units}&q={city_q}')
        #query_dtl =query_url +city_q
        #print (query_dtl)
        print ("----------------------------------------------------------------")
    except:
        print (f"Weather for {city_q} not found.")
        print ("----------------------------------------------------------------")
        continue
# Out:
# albany
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=albany
# ----------------------------------------------------------------
# hurricane
# Processing record #2 -- hurricane
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hurricane
# ----------------------------------------------------------------
# kiunga
# Processing record #3 -- kiunga
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=kiunga
# ----------------------------------------------------------------
# ocara
# Processing record #4 -- ocara
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ocara
# ----------------------------------------------------------------
# upernavik
# Processing record #5 -- upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=upernavik
# ----------------------------------------------------------------
# boueni
# Processing record #6 -- boueni
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=boueni
# ----------------------------------------------------------------
# khatanga
# Processing record #7 -- khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=khatanga
# ----------------------------------------------------------------
# brae
# Processing record #8 -- brae
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=brae
# ----------------------------------------------------------------
# buin
# Processing record #9 -- buin
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=buin
# ----------------------------------------------------------------
# albany
# Processing record #10 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=albany
# ----------------------------------------------------------------
# mataura
# Processing record #11 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mataura
# ----------------------------------------------------------------
# atuona
# Processing record #12 -- atuona
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=atuona
# ----------------------------------------------------------------
# san patricio
# Processing record #13 -- san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=san patricio
# ----------------------------------------------------------------
# guerrero negro
# Processing record #14 -- guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=guerrero negro
# ----------------------------------------------------------------
# bermejo
# Processing record #15 -- bermejo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bermejo
# ----------------------------------------------------------------
# vaini
# Processing record #16 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=vaini
# ----------------------------------------------------------------
# atuona
# Processing record #17 -- atuona
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=atuona
# ----------------------------------------------------------------
# leopold
# Processing record #18 -- leopold
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=leopold
# ----------------------------------------------------------------
# aksarka
# Processing record #19 -- aksarka
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=aksarka
# ----------------------------------------------------------------
# mar del plata
# Processing record #20 -- mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mar del plata
# ----------------------------------------------------------------
# labutta
# Weather for labutta not found.
# ----------------------------------------------------------------
# bandarbeyla
# Processing record #22 -- bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bandarbeyla
# ----------------------------------------------------------------
# nizhneyansk
# Weather for nizhneyansk not found.
# ----------------------------------------------------------------
# koutsouras
# Processing record #24 -- koutsouras
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=koutsouras
# ----------------------------------------------------------------
# mataura
# Processing record #25 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mataura
# ----------------------------------------------------------------
# alenquer
# Processing record #26 -- alenquer
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=alenquer
# ----------------------------------------------------------------
# koslan
# Processing record #27 -- koslan
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=koslan
# ----------------------------------------------------------------
# rikitea
# Processing record #28 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=rikitea
# ----------------------------------------------------------------
# cherskiy
# Processing record #29 -- cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=cherskiy
# ----------------------------------------------------------------
# ponta do sol
# Processing record #30 -- ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ponta do sol
# ----------------------------------------------------------------
# saint-philippe
# Processing record #31 -- saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=saint-philippe
# ----------------------------------------------------------------
# barrow
# Processing record #32 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=barrow
# ----------------------------------------------------------------
# thilogne
# Weather for thilogne not found.
# ----------------------------------------------------------------
# honiara
# Processing record #34 -- honiara
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=honiara
# ----------------------------------------------------------------
# mataura
# Processing record #35 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mataura
# ----------------------------------------------------------------
# ust-kamchatsk
# Weather for ust-kamchatsk not found.
# ----------------------------------------------------------------
# imbituba
# Processing record #37 -- imbituba
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=imbituba
# ----------------------------------------------------------------
# majene
# Processing record #38 -- majene
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=majene
# ----------------------------------------------------------------
# biltine
# Processing record #39 -- biltine
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=biltine
# ----------------------------------------------------------------
# pathein
# Processing record #40 -- pathein
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=pathein
# ----------------------------------------------------------------
# hermanus
# Processing record #41 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hermanus
# ----------------------------------------------------------------
# mataura
# Processing record #42 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mataura
# ----------------------------------------------------------------
# paita
# Processing record #43 -- paita
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=paita
# ----------------------------------------------------------------
# albany
# Processing record #44 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=albany
# ----------------------------------------------------------------
# vaitupu
# Weather for vaitupu not found.
# ----------------------------------------------------------------
# hobart
# Processing record #46 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hobart
# ----------------------------------------------------------------
# gat
# Processing record #47 -- gat
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=gat
# ----------------------------------------------------------------
# barrow
# Processing record #48 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=barrow
# ----------------------------------------------------------------
# rikitea
# Processing record #49 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=rikitea
# ----------------------------------------------------------------
# rikitea
# Processing record #50 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=rikitea
# ----------------------------------------------------------------
# lorengau
# Processing record #51 -- lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=lorengau
# ----------------------------------------------------------------
# hermanus
# Processing record #52 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hermanus
# ----------------------------------------------------------------
# taoudenni
# Processing record #53 -- taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=taoudenni
# ----------------------------------------------------------------
# hermanus
# Processing record #54 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hermanus
# ----------------------------------------------------------------
# cape town
# Processing record #55 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=cape town
# ----------------------------------------------------------------
# butaritari
# Processing record #56 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=butaritari
# ----------------------------------------------------------------
# busselton
# Processing record #57 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=busselton
# ----------------------------------------------------------------
# rikitea
# Processing record #58 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=rikitea
# ----------------------------------------------------------------
# cidreira
# Processing record #59 -- cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=cidreira
# ----------------------------------------------------------------
# port macquarie
# Processing record #60 -- port macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=port macquarie
# ----------------------------------------------------------------
# tasiilaq
# Processing record #61 -- tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=tasiilaq
# ----------------------------------------------------------------
# taozhuang
# Processing record #62 -- taozhuang
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=taozhuang
# ----------------------------------------------------------------
# belushya guba
# Weather for belushya guba not found.
# ----------------------------------------------------------------
# tidore
# Weather for tidore not found.
# ----------------------------------------------------------------
# rikitea
# Processing record #65 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=rikitea
# ----------------------------------------------------------------
# cape town
# Processing record #66 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=cape town
# ----------------------------------------------------------------
# ati
# Processing record #67 -- ati
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ati
# ----------------------------------------------------------------
# atuona
# Processing record #68 -- atuona
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=atuona
# ----------------------------------------------------------------
# hilo
# Processing record #69 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hilo
# ----------------------------------------------------------------
# uitenhage
# Processing record #70 -- uitenhage
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=uitenhage
# ----------------------------------------------------------------
# bonthe
# Processing record #71 -- bonthe
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bonthe
# ----------------------------------------------------------------
# rio grande
# Processing record #72 -- rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=rio grande
# ----------------------------------------------------------------
# inhambane
# Processing record #73 -- inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=inhambane
# ----------------------------------------------------------------
# chokurdakh
# Processing record #74 -- chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=chokurdakh
# ----------------------------------------------------------------
# mataura
# Processing record #75 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mataura
# ----------------------------------------------------------------
# victoria
# Processing record #76 -- victoria
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=victoria
# ----------------------------------------------------------------
# rikitea
# Processing record #77 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=rikitea
# ----------------------------------------------------------------
# tawang
# Processing record #78 -- tawang
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=tawang
# ----------------------------------------------------------------
# erie
# Processing record #79 -- erie
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=erie
# ----------------------------------------------------------------
# ankazoabo
# Processing record #80 -- ankazoabo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ankazoabo
# ----------------------------------------------------------------
# canitas
# Weather for canitas not found.
# ----------------------------------------------------------------
# nhulunbuy
# Processing record #82 -- nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=nhulunbuy
# ----------------------------------------------------------------
# hermanus
# Processing record #83 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hermanus
# ----------------------------------------------------------------
# bluff
# Processing record #84 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bluff
# ----------------------------------------------------------------
# ushuaia
# Processing record #85 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# port-de-paix
# Weather for port-de-paix not found.
# ----------------------------------------------------------------
# contai
# Processing record #87 -- contai
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=contai
# ----------------------------------------------------------------
# kapaa
# Processing record #88 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=kapaa
# ----------------------------------------------------------------
# new norfolk
# Processing record #89 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# upernavik
# Processing record #90 -- upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=upernavik
# ----------------------------------------------------------------
# fairbanks
# Processing record #91 -- fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=fairbanks
# ----------------------------------------------------------------
# huarmey
# Processing record #92 -- huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=huarmey
# ----------------------------------------------------------------
# albany
# Processing record #93 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=albany
# ----------------------------------------------------------------
# port alfred
# Processing record #94 -- port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=port alfred
# ----------------------------------------------------------------
# san patricio
# Processing record #95 -- san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=san patricio
# ----------------------------------------------------------------
# puerto el triunfo
# Processing record #96 -- puerto el triunfo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=puerto el triunfo
# ----------------------------------------------------------------
# severobaykalsk
# Processing record #97 -- severobaykalsk
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=severobaykalsk
# ----------------------------------------------------------------
# port elizabeth
# Processing record #98 -- port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=port elizabeth
# ----------------------------------------------------------------
# barrow
# Processing record #99 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=barrow
# ----------------------------------------------------------------
# hilo
# Processing record #100 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hilo
# ----------------------------------------------------------------
# hilo
# Processing record #101 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hilo
# ----------------------------------------------------------------
# san quintin
# Processing record #102 -- san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=san quintin
# ----------------------------------------------------------------
# severomorsk
# Processing record #103 -- severomorsk
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=severomorsk
# ----------------------------------------------------------------
# alofi
# Processing record #104 -- alofi
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=alofi
# ----------------------------------------------------------------
# pitimbu
# Processing record #105 -- pitimbu
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=pitimbu
# ----------------------------------------------------------------
# thompson
# Processing record #106 -- thompson
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=thompson
# ----------------------------------------------------------------
# vaitupu
# Weather for vaitupu not found.
# ----------------------------------------------------------------
# boyolangu
# Processing record #108 -- boyolangu
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=boyolangu
# ----------------------------------------------------------------
# khatanga
# Processing record #109 -- khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=khatanga
# ----------------------------------------------------------------
# attawapiskat
# Weather for attawapiskat not found.
# ----------------------------------------------------------------
# taolanaro
# Weather for taolanaro not found.
# ----------------------------------------------------------------
# rio gallegos
# Processing record #112 -- rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=rio gallegos
# ----------------------------------------------------------------
# bethel
# Processing record #113 -- bethel
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bethel
# ----------------------------------------------------------------
# dikson
# Processing record #114 -- dikson
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=dikson
# ----------------------------------------------------------------
# port hardy
# Processing record #115 -- port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=port hardy
# ----------------------------------------------------------------
# ojinaga
# Processing record #116 -- ojinaga
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ojinaga
# ----------------------------------------------------------------
# minab
# Processing record #117 -- minab
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=minab
# ----------------------------------------------------------------
# amderma
# Weather for amderma not found.
# ----------------------------------------------------------------
# kodiak
# Processing record #119 -- kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=kodiak
# ----------------------------------------------------------------
# bambous virieux
# Processing record #120 -- bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bambous virieux
# ----------------------------------------------------------------
# ushuaia
# Processing record #121 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# thompson
# Processing record #122 -- thompson
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=thompson
# ----------------------------------------------------------------
# moshupa
# Processing record #123 -- moshupa
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=moshupa
# ----------------------------------------------------------------
# barentsburg
# Weather for barentsburg not found.
# ----------------------------------------------------------------
# ossora
# Processing record #125 -- ossora
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ossora
# ----------------------------------------------------------------
# sitka
# Processing record #126 -- sitka
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=sitka
# ----------------------------------------------------------------
# hithadhoo
# Processing record #127 -- hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hithadhoo
# ----------------------------------------------------------------
# kenora
# Processing record #128 -- kenora
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=kenora
# ----------------------------------------------------------------
# puerto ayora
# Processing record #129 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# sentyabrskiy
# Weather for sentyabrskiy not found.
# ----------------------------------------------------------------
# east london
# Processing record #131 -- east london
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=east london
# ----------------------------------------------------------------
# longlac
# Weather for longlac not found.
# ----------------------------------------------------------------
# kajaani
# Processing record #133 -- kajaani
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=kajaani
# ----------------------------------------------------------------
# mbeya
# Processing record #134 -- mbeya
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mbeya
# ----------------------------------------------------------------
# saint-philippe
# Processing record #135 -- saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=saint-philippe
# ----------------------------------------------------------------
# vila velha
# Processing record #136 -- vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=vila velha
# ----------------------------------------------------------------
# sept-iles
# Processing record #137 -- sept-iles
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=sept-iles
# ----------------------------------------------------------------
# ushuaia
# Processing record #138 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# punta arenas
# Processing record #139 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# padang
# Processing record #140 -- padang
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=padang
# ----------------------------------------------------------------
# tasiilaq
# Processing record #141 -- tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=tasiilaq
# ----------------------------------------------------------------
# rikitea
# Processing record #142 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=rikitea
# ----------------------------------------------------------------
# cherskiy
# Processing record #143 -- cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=cherskiy
# ----------------------------------------------------------------
# bluff
# Processing record #144 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bluff
# ----------------------------------------------------------------
# corinto
# Processing record #145 -- corinto
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=corinto
# ----------------------------------------------------------------
# barentsburg
# Weather for barentsburg not found.
# ----------------------------------------------------------------
# mataura
# Processing record #147 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mataura
# ----------------------------------------------------------------
# puri
# Processing record #148 -- puri
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=puri
# ----------------------------------------------------------------
# iqaluit
# Processing record #149 -- iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=iqaluit
# ----------------------------------------------------------------
# barrow
# Processing record #150 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=barrow
# ----------------------------------------------------------------
# hilo
# Processing record #151 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hilo
# ----------------------------------------------------------------
# omboue
# Processing record #152 -- omboue
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=omboue
# ----------------------------------------------------------------
# port alfred
# Processing record #153 -- port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=port alfred
# ----------------------------------------------------------------
# hilo
# Processing record #154 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hilo
# ----------------------------------------------------------------
# port keats
# Processing record #155 -- port keats
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=port keats
# ----------------------------------------------------------------
# bluff
# Processing record #156 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bluff
# ----------------------------------------------------------------
# laguna
# Processing record #157 -- laguna
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=laguna
# ----------------------------------------------------------------
# port elizabeth
# Processing record #158 -- port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=port elizabeth
# ----------------------------------------------------------------
# lavrentiya
# Processing record #159 -- lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=lavrentiya
# ----------------------------------------------------------------
# biga
# Processing record #160 -- biga
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=biga
# ----------------------------------------------------------------
# puerto ayora
# Processing record #161 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# yellowknife
# Processing record #162 -- yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=yellowknife
# ----------------------------------------------------------------
# broken hill
# Processing record #163 -- broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=broken hill
# ----------------------------------------------------------------
# new norfolk
# Processing record #164 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# alice springs
# Processing record #165 -- alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=alice springs
# ----------------------------------------------------------------
# vaini
# Processing record #166 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=vaini
# ----------------------------------------------------------------
# antofagasta
# Processing record #167 -- antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=antofagasta
# ----------------------------------------------------------------
# bandar-e anzali
# Processing record #168 -- bandar-e anzali
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bandar-e anzali
# ----------------------------------------------------------------
# kendari
# Processing record #169 -- kendari
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=kendari
# ----------------------------------------------------------------
# tulun
# Processing record #170 -- tulun
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=tulun
# ----------------------------------------------------------------
# attawapiskat
# Weather for attawapiskat not found.
# ----------------------------------------------------------------
# belushya guba
# Weather for belushya guba not found.
# ----------------------------------------------------------------
# kapaa
# Processing record #173 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=kapaa
# ----------------------------------------------------------------
# ushuaia
# Processing record #174 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# stornoway
# Processing record #175 -- stornoway
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=stornoway
# ----------------------------------------------------------------
# tunceli
# Processing record #176 -- tunceli
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=tunceli
# ----------------------------------------------------------------
# vila velha
# Processing record #177 -- vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=vila velha
# ----------------------------------------------------------------
# punta arenas
# Processing record #178 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# carnarvon
# Processing record #179 -- carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=carnarvon
# ----------------------------------------------------------------
# lahat
# Processing record #180 -- lahat
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=lahat
# ----------------------------------------------------------------
# tuktoyaktuk
# Processing record #181 -- tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=tuktoyaktuk
# ----------------------------------------------------------------
# attawapiskat
# Weather for attawapiskat not found.
# ----------------------------------------------------------------
# maragogi
# Processing record #183 -- maragogi
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=maragogi
# ----------------------------------------------------------------
# san patricio
# Processing record #184 -- san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=san patricio
# ----------------------------------------------------------------
# hasaki
# Processing record #185 -- hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hasaki
# ----------------------------------------------------------------
# bredasdorp
# Processing record #186 -- bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bredasdorp
# ----------------------------------------------------------------
# tsihombe
# Weather for tsihombe not found.
# ----------------------------------------------------------------
# talnakh
# Processing record #188 -- talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=talnakh
# ----------------------------------------------------------------
# barrow
# Processing record #189 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=barrow
# ----------------------------------------------------------------
# castro
# Processing record #190 -- castro
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=castro
# ----------------------------------------------------------------
# albany
# Processing record #191 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=albany
# ----------------------------------------------------------------
# butaritari
# Processing record #192 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=butaritari
# ----------------------------------------------------------------
# jinchang
# Processing record #193 -- jinchang
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=jinchang
# ----------------------------------------------------------------
# bethel
# Processing record #194 -- bethel
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bethel
# ----------------------------------------------------------------
# pevek
# Processing record #195 -- pevek
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=pevek
# ----------------------------------------------------------------
# vila franca do campo
# Processing record #196 -- vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=vila franca do campo
# ----------------------------------------------------------------
# mataura
# Processing record #197 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mataura
# ----------------------------------------------------------------
# hobart
# Processing record #198 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hobart
# ----------------------------------------------------------------
# luderitz
# Processing record #199 -- luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=luderitz
# ----------------------------------------------------------------
# namibe
# Processing record #200 -- namibe
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=namibe
# ----------------------------------------------------------------
# tasiilaq
# Processing record #201 -- tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=tasiilaq
# ----------------------------------------------------------------
# nanortalik
# Processing record #202 -- nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=nanortalik
# ----------------------------------------------------------------
# campanha
# Processing record #203 -- campanha
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=campanha
# ----------------------------------------------------------------
# leningradskiy
# Processing record #204 -- leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=leningradskiy
# ----------------------------------------------------------------
# ushuaia
# Processing record #205 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# codrington
# Processing record #206 -- codrington
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=codrington
# ----------------------------------------------------------------
# carnarvon
# Processing record #207 -- carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=carnarvon
# ----------------------------------------------------------------
# warqla
# Weather for warqla not found.
# ----------------------------------------------------------------
# suao
# Weather for suao not found.
# ----------------------------------------------------------------
# gizo
# Processing record #210 -- gizo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=gizo
# ----------------------------------------------------------------
# barawe
# Weather for barawe not found.
# ----------------------------------------------------------------
# kenai
# Processing record #212 -- kenai
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=kenai
# ----------------------------------------------------------------
# yellowknife
# Processing record #213 -- yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=yellowknife
# ----------------------------------------------------------------
# cabo san lucas
# Processing record #214 -- cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=cabo san lucas
# ----------------------------------------------------------------
# jamestown
# Processing record #215 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=jamestown
# ----------------------------------------------------------------
# iquitos
# Processing record #216 -- iquitos
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=iquitos
# ----------------------------------------------------------------
# puerto ayora
# Processing record #217 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# puerto lopez
# Processing record #218 -- puerto lopez
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=puerto lopez
# ----------------------------------------------------------------
# chopda
# Processing record #219 -- chopda
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=chopda
# ----------------------------------------------------------------
# tecoanapa
# Processing record #220 -- tecoanapa
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=tecoanapa
# ----------------------------------------------------------------
# tsihombe
# Weather for tsihombe not found.
# ----------------------------------------------------------------
# ahuimanu
# Processing record #222 -- ahuimanu
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ahuimanu
# ----------------------------------------------------------------
# faanui
# Processing record #223 -- faanui
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=faanui
# ----------------------------------------------------------------
# murray bridge
# Processing record #224 -- murray bridge
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=murray bridge
# ----------------------------------------------------------------
# oak ridge
# Processing record #225 -- oak ridge
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=oak ridge
# ----------------------------------------------------------------
# ushuaia
# Processing record #226 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# dikson
# Processing record #227 -- dikson
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=dikson
# ----------------------------------------------------------------
# bowen
# Processing record #228 -- bowen
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bowen
# ----------------------------------------------------------------
# san cristobal
# Processing record #229 -- san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=san cristobal
# ----------------------------------------------------------------
# ushuaia
# Processing record #230 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# bengkulu
# ...
# ----------------------------------------------------------------
# cape town
# Processing record #625 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=cape town
# ----------------------------------------------------------------
# ushuaia
# Processing record #626 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# mahebourg
# Processing record #627 -- mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mahebourg
# ----------------------------------------------------------------
# chuy
# Processing record #628 -- chuy
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=chuy
# ----------------------------------------------------------------
# verkhnevilyuysk
# Processing record #629 -- verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=verkhnevilyuysk
# ----------------------------------------------------------------
# vaini
# Processing record #630 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=vaini
# ----------------------------------------------------------------
# nome
# Processing record #631 -- nome
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=nome
# ----------------------------------------------------------------
# narsaq
# Processing record #632 -- narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=narsaq
# ----------------------------------------------------------------
# mar del plata
# Processing record #633 -- mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mar del plata
# ----------------------------------------------------------------
# busselton
# Processing record #634 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=busselton
# ----------------------------------------------------------------
# cape town
# Processing record #635 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=cape town
# ----------------------------------------------------------------
# mataura
# Processing record #636 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mataura
# ----------------------------------------------------------------
# guerrero negro
# Processing record #637 -- guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=guerrero negro
# ----------------------------------------------------------------
# mataura
# Processing record #638 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=mataura
# ----------------------------------------------------------------
# severo-kurilsk
# Processing record #639 -- severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=severo-kurilsk
# ----------------------------------------------------------------
# umzimvubu
# Weather for umzimvubu not found.
# ----------------------------------------------------------------
# albany
# Processing record #641 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=albany
# ----------------------------------------------------------------
# isangel
# Processing record #642 -- isangel
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=isangel
# ----------------------------------------------------------------
# barrow
# Processing record #643 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=barrow
# ----------------------------------------------------------------
# aguadilla
# Processing record #644 -- aguadilla
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=aguadilla
# ----------------------------------------------------------------
# vaini
# Processing record #645 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=vaini
# ----------------------------------------------------------------
# barrow
# Processing record #646 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=barrow
# ----------------------------------------------------------------
# hofn
# Processing record #647 -- hofn
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hofn
# ----------------------------------------------------------------
# tsihombe
# Weather for tsihombe not found.
# ----------------------------------------------------------------
# ilo
# Processing record #649 -- ilo
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ilo
# ----------------------------------------------------------------
# rio gallegos
# Processing record #650 -- rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=rio gallegos
# ----------------------------------------------------------------
# provideniya
# Processing record #651 -- provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=provideniya
# ----------------------------------------------------------------
# dikson
# Processing record #652 -- dikson
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=dikson
# ----------------------------------------------------------------
# ushuaia
# Processing record #653 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# saint-philippe
# Processing record #654 -- saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=saint-philippe
# ----------------------------------------------------------------
# dunedin
# Processing record #655 -- dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=dunedin
# ----------------------------------------------------------------
# husavik
# Processing record #656 -- husavik
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=husavik
# ----------------------------------------------------------------
# hermanus
# Processing record #657 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=hermanus
# ----------------------------------------------------------------
# cape town
# Processing record #658 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=cape town
# ----------------------------------------------------------------
# marawi
# Processing record #659 -- marawi
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=marawi
# ----------------------------------------------------------------
# carnarvon
# Processing record #660 -- carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=carnarvon
# ----------------------------------------------------------------
# lata
# Processing record #661 -- lata
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=lata
# ----------------------------------------------------------------
# vaini
# Processing record #662 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=vaini
# ----------------------------------------------------------------
# ushuaia
# Processing record #663 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# jamestown
# Processing record #664 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=jamestown
# ----------------------------------------------------------------
# khani
# Processing record #665 -- khani
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=khani
# ----------------------------------------------------------------
# ushuaia
# Processing record #666 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# mys shmidta
# Weather for mys shmidta not found.
# ----------------------------------------------------------------
# yellowknife
# Processing record #668 -- yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=yellowknife
# ----------------------------------------------------------------
# bowen
# Processing record #669 -- bowen
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bowen
# ----------------------------------------------------------------
# barrow
# Processing record #670 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=barrow
# ----------------------------------------------------------------
# narsaq
# Processing record #671 -- narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=narsaq
# ----------------------------------------------------------------
# bereda
# Processing record #672 -- bereda
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bereda
# ----------------------------------------------------------------
# atasu
# Processing record #673 -- atasu
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=atasu
# ----------------------------------------------------------------
# tsihombe
# Weather for tsihombe not found.
# ----------------------------------------------------------------
# sinop
# Processing record #675 -- sinop
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=sinop
# ----------------------------------------------------------------
# port hedland
# Processing record #676 -- port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=port hedland
# ----------------------------------------------------------------
# saint-joseph
# Processing record #677 -- saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=saint-joseph
# ----------------------------------------------------------------
# cape town
# Processing record #678 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=cape town
# ----------------------------------------------------------------
# talnakh
# Processing record #679 -- talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=talnakh
# ----------------------------------------------------------------
# morondava
# Processing record #680 -- morondava
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=morondava
# ----------------------------------------------------------------
# illoqqortoormiut
# Weather for illoqqortoormiut not found.
# ----------------------------------------------------------------
# east london
# Processing record #682 -- east london
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=east london
# ----------------------------------------------------------------
# jamestown
# Processing record #683 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=jamestown
# ----------------------------------------------------------------
# vaini
# Processing record #684 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=vaini
# ----------------------------------------------------------------
# qaanaaq
# Processing record #685 -- qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=qaanaaq
# ----------------------------------------------------------------
# saint george
# Processing record #686 -- saint george
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=saint george
# ----------------------------------------------------------------
# haibowan
# Weather for haibowan not found.
# ----------------------------------------------------------------
# attawapiskat
# Weather for attawapiskat not found.
# ----------------------------------------------------------------
# dikson
# Processing record #689 -- dikson
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=dikson
# ----------------------------------------------------------------
# mys shmidta
# Weather for mys shmidta not found.
# ----------------------------------------------------------------
# bengkulu
# Processing record #691 -- bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bengkulu
# ----------------------------------------------------------------
# pevek
# Processing record #692 -- pevek
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=pevek
# ----------------------------------------------------------------
# souillac
# Processing record #693 -- souillac
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=souillac
# ----------------------------------------------------------------
# ushuaia
# Processing record #694 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# bethel
# Processing record #695 -- bethel
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=bethel
# ----------------------------------------------------------------
# butaritari
# Processing record #696 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=butaritari
# ----------------------------------------------------------------
# qaqortoq
# Processing record #697 -- qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=qaqortoq
# ----------------------------------------------------------------
# tasiilaq
# Processing record #698 -- tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=tasiilaq
# ----------------------------------------------------------------
# methoni
# Processing record #699 -- methoni
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=methoni
# ----------------------------------------------------------------
# esperance
# Processing record #700 -- esperance
# http://api.openweathermap.org/data/2.5/weather?appid=a6e1b67de599342fd4e1832fcfeaa76f&units=imperial&q=esperance
# ----------------------------------------------------------------

# %%
#get count of collected data in the weather_df dataframe that is ready to get exported to csv file with certain information
print (len(city_weather_data))
# Out:
# 627

# %%
weather_df=pd.DataFrame(city_weather_data)
weather_df
#weather_df=weather_df[["City", "Country","Latitude","Longitude","Temperature (F)", "Humidity (%)", "Cloudiness (%)", "Wind Speed (MPH)"]]
weather_df.head()
# Out:
#         City Country  Latitude  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0     Albany      US     42.60            42.44           100               1
# 1  Hurricane      US     37.18            31.10            86               1
# 2     Kiunga      PG     -6.12            76.86            94              97
# 3      Ocara      BR     -4.49            84.60            57              24
# 4  Upernavik      GL     72.79             5.02            84             100
#
#    Wind Speed (MPH)
# 0              2.08
# 1              3.36
# 2              4.38
# 3              7.87
# 4              8.63

# %%
# Now wite this new data frame created to csv file
weather_df.to_csv("output/weather_data.csv")

# %%
# create scatter plots with lattidudes against temp, humidity, cloudiness and wind speed 
date = datetime.now()
date = date.strftime("%m-%d-%Y")

plt.scatter(weather_df["Latitude"], weather_df["Temperature (F)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Temperature ($^\circ$F)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("output/fig1.png")
plt.show()

# %%
# create scatter plots with lattidudes against temp, humidity, cloudiness and wind speed 
date = datetime.now()
date = date.strftime("%m-%d-%Y")

plt.scatter(weather_df["Latitude"], weather_df["Humidity (%)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Humidity (%)")
plt.grid(True) 
plt.tight_layout()

plt.savefig("output/fig2.png")
plt.show()

# %%
# create scatter plots with lattidudes against temp, humidity, cloudiness and wind speed 
date = datetime.now()
date = date.strftime("%m-%d-%Y")

plt.scatter(weather_df["Latitude"], weather_df["Cloudiness (%)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Cloudiness (%)")
plt.grid(True) 
plt.tight_layout()

plt.savefig("output/fig3.png")
plt.show()

# %%
# create scatter plots with lattidudes against temp, humidity, cloudiness and wind speed 
date = datetime.now()
date = date.strftime("%m-%d-%Y")

plt.scatter(weather_df["Latitude"], weather_df["Wind Speed (MPH)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Wind Speed (MPH)")
plt.grid(True) 
plt.tight_layout()

plt.savefig("output/fig4.png")
plt.show()

# %%
# OBSERVATIONS:
# It seems that city temps are hotter near the equator.(First Graph Latidude vs Temp).

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df.loc[weather_df["Latitude"] >= 0]
southern_hemisphere = weather_df.loc[weather_df["Latitude"] < 0]

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression¶

equation = linear_agression(northern_hemisphere["Latitude"], northern_hemisphere["Temperature (F)"])
annotate(equation, 0, 0)
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("output/NortHemispere-MaxTempv-LLR.png")
# Out:
# The r-squared is : -0.92

# %%
#Southern Hemisphere - Temp vs. Latitude Linear Regression

equation = linear_agression(southern_hemisphere["Latitude"], southern_hemisphere["Humidity (%)"])
annotate(equation, -40, 50)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("output/SouthHemisphere-Humidity-LLR.png")
# Out:
# The r-squared is : -0.06

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression¶

equation = linear_agression(northern_hemisphere["Latitude"], northern_hemisphere["Cloudiness (%)"])
annotate(equation, 30, 40)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("output/NorthernHemisphere-Cloudiness-LLR.png")
# Out:
# The r-squared is : 0.37

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

equation = linear_agression(southern_hemisphere["Latitude"], southern_hemisphere["Cloudiness (%)"])
annotate(equation, -30, 40)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("output/SouthernHemisphere-Cloudiness-LLR.png")
# Out:
# The r-squared is : -0.15

# %%
equation = linear_agression(northern_hemisphere["Latitude"], northern_hemisphere["Wind Speed (MPH)"])

annotate(equation, 40, 20)
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("output/NorthernHemisphere-WindSeed-LLR")
# Out:
# The r-squared is : 0.23

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

equation = linear_agression(southern_hemisphere["Latitude"], southern_hemisphere["Wind Speed (MPH)"])
annotate(equation, -30, 15)
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("output/SouthernHemisphere-WindSpeed-LLR.png")
# Out:
# The r-squared is : -0.08
